# %% [markdown]
# # Regular LSTM with PyTorch

# %% [markdown]
# Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from custom_lstm.models.lstm_custom_stateful import LSTMCustomStateful
from custom_lstm.losses.acf_losses import EWACFLoss
from sklearn.preprocessing import StandardScaler


device = torch.device("cuda" if not torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
print(f"Device name: {torch.cuda.get_device_name(0)}")
# Out:
# Using device: cpu
# Device name: NVIDIA GeForce RTX 4050 Laptop GPU

# %% [markdown]
# Import dataset

# %%
data = pd.read_csv("../data/raw/exchange_rate.csv")
data = data[["date", "2"]]
data = data.rename(columns={"2": "exchange_rate"})
data
# Out:
#             date  exchange_rate
# 0       1990/1/1       1.611000
# 1       1990/1/2       1.610000
# 2       1990/1/3       1.629300
# 3       1990/1/4       1.637000
# 4       1990/1/5       1.653000
# ...          ...            ...
# 7583   2010/10/6       1.222195
# 7584   2010/10/7       1.223459
# 7585   2010/10/8       1.234111
# 7586   2010/10/9       1.233905
# 7587  2010/10/10       1.233905
#
# [7588 rows x 2 columns]

# %% [markdown]
# Preprocess data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7588 entries, 0 to 7587
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           7588 non-null   object
#  1   exchange_rate  7588 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 118.7+ KB

# %%
print("Number of NaN values in the dataset: ", data.isnull().sum())
data.dropna(inplace=True)
data.isnull().sum()
# Out:
# Number of NaN values in the dataset:  date             0
# exchange_rate    0
# dtype: int64
# date             0
# exchange_rate    0
# dtype: int64

# %% [markdown]
# Get non-numeric characters

# %%
# data['min_temp'] = data['min_temp'].apply(lambda x: x.replace('?', '-'))

# %% [markdown]
# Convert date and string columns to numeric values

# %%
data["date"] = pd.to_datetime(data["date"])
# data['min_temp'] = pd.to_numeric(data['min_temp'])

# %% [markdown]
# View Dataset

# %%
plt.figure(figsize=(12, 6))
plt.plot(data["date"], data["exchange_rate"])
plt.show()

# %% [markdown]
# ### Create Batches Maintaining Temporal Structure

# %% [markdown]
# Train/Test Split

# %%
# t = np.linspace(0, 100, 2000)
# data = np.sin(0.2*t) + 0.8*np.sin(0.1*t) + 0.1*np.random.randn(len(t))

# %%
TRAIN_SIZE = 0.8
time_series = data["exchange_rate"].values

time_series_train = time_series[: int(len(time_series) * TRAIN_SIZE)].reshape(-1, 1)
time_series_test = time_series[int(len(time_series) * TRAIN_SIZE) :].reshape(-1, 1)

# %% [markdown]
# Normalize the data

# %%
scaler = StandardScaler()
time_series_train = scaler.fit_transform(time_series_train)
time_series_test = scaler.transform(time_series_test)

# %% [markdown]
# Transform numpy array to tensor

# %%
time_series_train = torch.from_numpy(time_series_train).unsqueeze(0).float()
time_series_test = torch.from_numpy(time_series_test).unsqueeze(0).float()

print("--- Tensors After Reshaping (Ready for LSTM) ---")
print("Time Series Train: ", time_series_train.shape)
print("Time Series Test: ", time_series_test.shape)
# Out:
# --- Tensors After Reshaping (Ready for LSTM) ---
# Time Series Train:  torch.Size([1, 6070, 1])
# Time Series Test:  torch.Size([1, 1518, 1])

# %% [markdown]
# Create batch sequences for training

# %%
BATCH_SIZE = 40
rounded_length = (time_series_train.shape[1] // BATCH_SIZE) * BATCH_SIZE
full_sequence = time_series_train[0, :rounded_length, :]

sequence_length = len(full_sequence) // BATCH_SIZE
sequences = full_sequence.reshape(BATCH_SIZE, sequence_length, 1)

X_train = torch.from_numpy(np.array(sequences)).float()
X_train.shape
# Out:
# C:\Users\Luis\AppData\Local\Temp\ipykernel_26260\3497012082.py:8: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   X_train = torch.from_numpy(np.array(sequences)).float()
# torch.Size([40, 151, 1])

# %% [markdown]
# Create batch sequences for testing

# %%
rounded_length = time_series_test.shape[1] // BATCH_SIZE * BATCH_SIZE
full_sequence = time_series_test[0, :rounded_length, :]

sequence_length = len(full_sequence) // BATCH_SIZE
sequence = full_sequence.reshape(BATCH_SIZE, sequence_length, 1)

X_test = torch.from_numpy(np.array(sequence)).float()
X_test.shape
# Out:
# C:\Users\Luis\AppData\Local\Temp\ipykernel_26260\2258485524.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   X_test = torch.from_numpy(np.array(sequence)).float()
# torch.Size([40, 37, 1])

# %%
x = torch.ones(10, 10, 10)
y = torch.mean(x)
y.shape
# Out:
# torch.Size([])

# %% [markdown]
# ### Train regular LSTM

# %%
# More Hyperparameters
EPOCHS = 500
WINDOW_SIZE = 10

model = LSTMCustomStateful(input_size=X_train.shape[2], hidden_size=16, output_size=1).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)
loss_function = nn.MSELoss()
acf_loss = EWACFLoss()

start_event = torch.cuda.Event(enable_timing=True)
end_event = torch.cuda.Event(enable_timing=True)
start_event.record()

# Shift the input data by one time step to the right and left
inputs = X_train[:, :-1, :]
targets = X_train[:, 1:, :]

inputs_test = X_test[:, :-1, :]
targets_test = X_test[:, 1:, :]
stream_len = inputs.shape[1]

# Training loop
for epoch in range(EPOCHS):
    acf_loss.reset_state()
    model.reset_state()
    model.train()

    train_loss_sum = 0
    train_batch_count = 0
    for i in range(0, inputs.shape[1], WINDOW_SIZE):
        X_batch = inputs[:, i : i + WINDOW_SIZE, :]
        y_batch = targets[:, i : i + WINDOW_SIZE, :]

        X_batch = X_batch.to(device)
        y_batch = y_batch.to(device)

        y_pred, forget_gates = model(X_batch)
        # loss = loss_function(y_pred, y_batch)
        loss = acf_loss(y_pred, y_batch, X_batch, forget_gates)

        optimizer.zero_grad()

        loss.backward()

        optimizer.step()

        train_loss_sum += loss.item()
        train_batch_count += 1

    avg_train_loss = train_loss_sum / train_batch_count

    # Test loop
    model.eval()
    test_loss_sum = 0
    test_batch_count = 0
    with torch.no_grad():
        model.reset_state()

        for i in range(0, X_test.shape[1], WINDOW_SIZE):
            X_batch = inputs_test[:, i : i + WINDOW_SIZE, :]
            y_batch = targets_test[:, i : i + WINDOW_SIZE, :]

            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)
            y_pred, _ = model(X_batch)
            test_loss_sum += loss_function(y_pred, y_batch).item()
            test_batch_count += 1

    avg_test_loss = test_loss_sum / test_batch_count

    if (epoch + 1) % 10 == 0:
        print(f"Epoch: {epoch + 1}, Test Loss: {avg_test_loss:.4f}, Train Loss: {avg_train_loss:.4f}")

end_event.record()
torch.cuda.synchronize()

elapsed_time_ms = start_event.elapsed_time(end_event)
elapsed_time_sec = elapsed_time_ms / 1000
minutes = int(elapsed_time_sec // 60)
seconds = int(elapsed_time_sec % 60)

print(f"\nTraining finished in {minutes} minutes and {seconds} seconds.")
# Out:
# Epoch: 10, Test Loss: 0.8070, Train Loss: 0.9574
# Epoch: 20, Test Loss: 0.7502, Train Loss: 0.8507
# Epoch: 30, Test Loss: 0.6656, Train Loss: 0.6732
# Epoch: 40, Test Loss: 0.5213, Train Loss: 0.3889
# Epoch: 50, Test Loss: 0.3736, Train Loss: 0.2662
# Epoch: 60, Test Loss: 0.2975, Train Loss: 0.2266
# Epoch: 70, Test Loss: 0.2653, Train Loss: 0.2055
# Epoch: 80, Test Loss: 0.2424, Train Loss: 0.1891
# Epoch: 90, Test Loss: 0.2217, Train Loss: 0.1760
# Epoch: 100, Test Loss: 0.2032, Train Loss: 0.1656
# Epoch: 110, Test Loss: 0.1869, Train Loss: 0.1573
# Epoch: 120, Test Loss: 0.1728, Train Loss: 0.1506
# Epoch: 130, Test Loss: 0.1608, Train Loss: 0.1451
# Epoch: 140, Test Loss: 0.1507, Train Loss: 0.1402
# Epoch: 150, Test Loss: 0.1424, Train Loss: 0.1358
# Epoch: 160, Test Loss: 0.1355, Train Loss: 0.1316
# Epoch: 170, Test Loss: 0.1299, Train Loss: 0.1275
# Epoch: 180, Test Loss: 0.1251, Train Loss: 0.1233
# Epoch: 190, Test Loss: 0.1212, Train Loss: 0.1190
# Epoch: 200, Test Loss: 0.1177, Train Loss: 0.1145
# Epoch: 210, Test Loss: 0.1146, Train Loss: 0.1098
# Epoch: 220, Test Loss: 0.1118, Train Loss: 0.1050
# Epoch: 230, Test Loss: 0.1090, Train Loss: 0.0999
# Epoch: 240, Test Loss: 0.1058, Train Loss: 0.0938
# Epoch: 250, Test Loss: 0.1021, Train Loss: 0.0873
# Epoch: 260, Test Loss: 0.0981, Train Loss: 0.0810
# Epoch: 270, Test Loss: 0.0943, Train Loss: 0.0749
# Epoch: 280, Test Loss: 0.0912, Train Loss: 0.0690
# Epoch: 290, Test Loss: 0.0893, Train Loss: 0.0633
# Epoch: 300, Test Loss: 0.0882, Train Loss: 0.0577
# Epoch: 310, Test Loss: 0.0874, Train Loss: 0.0521
# Epoch: 320, Test Loss: 0.0868, Train Loss: 0.0466
# Epoch: 330, Test Loss: 0.0857, Train Loss: 0.0410
# Epoch: 340, Test Loss: 0.0830, Train Loss: 0.0358
# Epoch: 350, Test Loss: 0.0793, Train Loss: 0.0310
# Epoch: 360, Test Loss: 0.0753, Train Loss: 0.0268
# Epoch: 370, Test Loss: 0.0712, Train Loss: 0.0233
# Epoch: 380, Test Loss: 0.0671, Train Loss: 0.0204
# Epoch: 390, Test Loss: 0.0630, Train Loss: 0.0180
# Epoch: 400, Test Loss: 0.0592, Train Loss: 0.0161
# Epoch: 410, Test Loss: 0.0558, Train Loss: 0.0145
# Epoch: 420, Test Loss: 0.0526, Train Loss: 0.0132
# Epoch: 430, Test Loss: 0.0498, Train Loss: 0.0121
# Epoch: 440, Test Loss: 0.0472, Train Loss: 0.0113
# Epoch: 450, Test Loss: 0.0449, Train Loss: 0.0106
# Epoch: 460, Test Loss: 0.0429, Train Loss: 0.0099
# Epoch: 470, Test Loss: 0.0413, Train Loss: 0.0094
# Epoch: 480, Test Loss: 0.0400, Train Loss: 0.0090
# Epoch: 490, Test Loss: 0.0388, Train Loss: 0.0086
# Epoch: 500, Test Loss: 0.0379, Train Loss: 0.0083
#
# Training finished in 0 minutes and 57 seconds.

# %% [markdown]
# Plot the results of the LSTM model

# %%
# Ensure the model is in evaluation mode
model.eval()

full_train = time_series_train[:, :-1, :].to(device)
full_test = time_series_test[:, :-1, :].to(device)
# --- 1. Get Predictions ---
with torch.no_grad():
    model.reset_state()
    y_train, _ = model(full_train)
    model.reset_state()
    y_test, _ = model(full_test)

predict_plot = scaler.inverse_transform(np.array(y_train.squeeze(0)))
train_plot = scaler.inverse_transform(np.array(time_series_train.squeeze(0)))

predict_test_plot = scaler.inverse_transform(np.array(y_test.squeeze(0)))
test_plot = scaler.inverse_transform(np.array(time_series_test.squeeze(0)))

# # --- 3. Create the Plot ---
plt.figure(figsize=(12, 6))
# plt.plot(range(len(train_plot)), train_plot, label='Actual Train Data')
# plt.plot(range(len(predict_plot)), predict_plot, label='Predicted Train Data')
plt.plot(range(len(test_plot)), test_plot, label="Actual Test Data")
plt.plot(range(len(predict_test_plot)), predict_test_plot, label="Predicted Test Data", linestyle="--")

plt.title("Data Predictions")
plt.xlabel("Time")
plt.ylabel("Y-Axis")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\Luis\AppData\Local\Temp\ipykernel_26260\3702506443.py:13: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   predict_plot = scaler.inverse_transform(np.array(y_train.squeeze(0)))
# C:\Users\Luis\AppData\Local\Temp\ipykernel_26260\3702506443.py:14: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   train_plot = scaler.inverse_transform(np.array(time_series_train.squeeze(0)))
# C:\Users\Luis\AppData\Local\Temp\ipykernel_26260\3702506443.py:16: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   predict_test_plot = scaler.inverse_transform(np.array(y_test.squeeze(0)))
# C:\Users\Luis\AppData\Local\Temp\ipykernel_26260\3702506443.py:17: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   test_plot = scaler.inverse_transform(np.array(time_series_test.squeeze(0)))
